# %%
import pandas as pd

data_path = "data.csv"
data_frame = pd.read_csv(data_path)

data_frame
# Out:
#     U(V) 365nm  I (10^-12 A) 365nm  U(V) 405nm  I (10^-12 A) 405nm  \
# 0          0.0                 390         0.0                 165
# 1         -0.1                 327        -0.1                 133
# 2         -0.2                 275        -0.2                 101
# 3         -0.3                 234        -0.3                  76
# 4         -0.4                 184        -0.4                  51
# 5         -0.5                 141        -0.5                  29
# 6         -0.6                  99        -0.6                  11
# 7         -0.7                  66        -0.7                  -3
# 8         -0.8                  32        -0.8                 -13
# 9         -0.9                   6        -0.9                 -20
# 10        -1.0                 -11        -1.0                 -24
# 11        -1.1                 -31        -1.1                 -27
# 12        -1.2                 -42        -1.2                 -28
# ...
